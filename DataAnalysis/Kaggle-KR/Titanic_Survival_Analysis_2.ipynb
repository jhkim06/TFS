# %% [markdown]
# ### 참고사이트 -> https://kaggle-kr.tistory.com/18?category=868316

# %% [markdown]
# # !! Feature Engineering !!

# %% [markdown]
# - 앞서 어느정도 feature의 조작이 있었으나, 이제부터 본격적으로 feature engineering을 시작함

# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib 의 기본 scheme 말고 seaborn scheme 을 세팅하고,
# 일일이 graph 의 font size 를 지정할 필요 없이 seaborn 의 font_scale 을 사용하면 편합니다.
plt.style.use('seaborn')
sns.set(font_scale=2.5) 

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

df_train = pd.read_csv('../Data/Titanic/train.csv')
df_test = pd.read_csv('../Data/Titanic/test.csv')
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1 # 자신을 포함해야하니 1을 더합니다

df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean()
# testset 에 있는 nan value 를 평균값으로 치환합니다.
# df_test에는 원래 1개의 NAN값이 있었다.

df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
df_test['Fare'] = df_test['Fare'].map(lambda i: np.log(i) if i > 0 else 0)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_train['Initial']= df_train.Name.str.extract('([A-Za-z]+)\.') # 정규표현식으로 마침표(.)에 이어진 표현을 추출한다.
df_test['Initial']= df_test.Name.str.extract('([A-Za-z]+)\.') # Mr. Dr. 등등이 대게 그런 단어다.

# %%
df_train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket      Fare Cabin Embarked  FamilySize Initial
# 0      0  A/5 21171  1.981001   NaN        S           2      Mr
# 1      0   PC 17599  4.266662   C85        C           2     Mrs

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e3e48218_8a95_11e9_ae1a_7cd1c3e683bdrow0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
# ...

# %%
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

# %% [markdown]
# - 복잡한 Initial 표현들을 단순한 표현들로 대체

# %%
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Initial
# Master    414.975000  0.575000  2.625000   4.574167  2.300000  1.375000
# Miss      411.741935  0.704301  2.284946  21.860000  0.698925  0.537634
# Mr        455.880907  0.162571  2.381853  32.739609  0.293006  0.151229
# Mrs       456.393701  0.795276  1.984252  35.981818  0.692913  0.818898
# Other     564.444444  0.111111  1.666667  45.888889  0.111111  0.111111
#
#              Fare  FamilySize
# Initial
# Master   3.340710    4.675000
# Miss     3.123713    2.236559
# Mr       2.651507    1.444234
# Mrs      3.443751    2.511811
# Other    2.641605    1.222222
